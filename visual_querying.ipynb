# %% [markdown]
# ### Setup & Imports

# %%
# %pip install Pillow sentence-transformers torch milvus pandas imageio pymilvus onnxruntime ftfy openai-clip matplotlib
# Out:
# Requirement already satisfied: Pillow in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (10.1.0)
# Requirement already satisfied: sentence-transformers in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torch in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: milvus in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: imageio in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (2.31.5)
# Requirement already satisfied: pymilvus in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: onnxruntime in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (1.16.3)
# Requirement already satisfied: ftfy in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (6.1.3)
# Requirement already satisfied: openai-clip in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (4.36.2)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torchvision in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (0.16.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (1.2.1)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (1.9.3)
# Requirement already satisfied: nltk in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/benedikt/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: grpcio<=1.58.0,>=1.49.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from pymilvus) (1.58.0)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from pymilvus) (4.23.4)
# Requirement already satisfied: environs<=9.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from pymilvus) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from pymilvus) (5.8.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from pymilvus) (2.31.0)
# Requirement already satisfied: minio>=7.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from pymilvus) (7.2.0)
# Requirement already satisfied: coloredlogs in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: packaging in /Users/benedikt/.local/lib/python3.10/site-packages (from onnxruntime) (23.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from ftfy) (0.2.13)
# Requirement already satisfied: regex in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from openai-clip) (2023.3.23)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from matplotlib) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: marshmallow>=3.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus) (3.20.1)
# Requirement already satisfied: python-dotenv in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus) (1.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus) (2023.11.17)
# Requirement already satisfied: urllib3 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus) (2.1.0)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus) (23.1.0)
# Requirement already satisfied: pycryptodome in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus) (3.19.0)
# Requirement already satisfied: six>=1.5 in /Users/benedikt/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from requests->pymilvus) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from requests->pymilvus) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from argon2-cffi->minio>=7.0.0->pymilvus) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->minio>=7.0.0->pymilvus) (1.16.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniconda/base/envs/everything/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio>=7.0.0->pymilvus) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run cliponnx/models.py
# %run cliponnx/simple_tokenizer.py

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from PIL import Image
import torch
import glob
import regex as rg
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from cliponnx.models import TextualModel, VisualModel
import math
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import precision_score

from helpers import *

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'mps')
torch.set_num_threads(10)

# %%
ground_truth_de, ground_truth_en = create_ground_truth_dicts()
# print(ground_truth_de)
# print(ground_truth_en)

# %% [markdown]
# ### Model 1: CLIP+Vision Transformers (ViT) model with multilingual training

# %%
img_model = SentenceTransformer('clip-ViT-B-32').to(device)
text_model = SentenceTransformer('sentence-transformers/clip-ViT-B-32-multilingual-v1').to(device)
emb_dims=512
cliparts = None
cliparts_txt = None

# %%
from pymilvus import (
    connections,
    utility,
    FieldSchema,
    CollectionSchema,
    DataType,
    Collection,
)
connections.connect("default", host="localhost", port="19530")

# %%
def drop_collections():
    utility.drop_collection("cliparts")
    utility.drop_collection("cliparts_txt")

# %%
def setup_collections():
    global cliparts
    global cliparts_txt
    fields = [
        FieldSchema(name="pk", dtype=DataType.INT64, is_primary=True, auto_id=True),
        FieldSchema(name="img_embeddings", dtype=DataType.FLOAT_VECTOR, dim=emb_dims),
        FieldSchema(name="text", dtype=DataType.VARCHAR, dim=emb_dims, max_length=1024),
        FieldSchema(name="path", dtype=DataType.VARCHAR, dim=emb_dims, max_length=1024),
        FieldSchema(name='txt_embeddings', dtype=DataType.ARRAY, element_type=DataType.FLOAT, max_capacity=emb_dims)
    ]
    schema = CollectionSchema(fields, "Clipart collection")
    cliparts = Collection("cliparts", schema,
            enable_dynamic_field=True)
    fields = [
        FieldSchema(name="pk", dtype=DataType.INT64, is_primary=True, auto_id=True),
        FieldSchema(name="txt_embeddings", dtype=DataType.FLOAT_VECTOR, dim=emb_dims),
        FieldSchema(name="text", dtype=DataType.VARCHAR, dim=emb_dims, max_length=1024),
        FieldSchema(name="path", dtype=DataType.VARCHAR, dim=emb_dims, max_length=1024),
        FieldSchema(name='img_embeddings', dtype=DataType.ARRAY, element_type=DataType.FLOAT, max_capacity=emb_dims)
    ]
    schema = CollectionSchema(fields, "Clipart collection (text vectors)")
    cliparts_txt = Collection("cliparts_txt", schema,
            enable_dynamic_field=True)

# %%
def create_indices():
    global cliparts
    global cliparts_txt
    
    cliparts.create_index(
        field_name="img_embeddings",
        index_params={
            "metric_type": "COSINE",
            "index_type": "IVF_FLAT",
            "params": {"nlist": 1024},
        },
    )
    cliparts_txt.create_index(
        field_name="txt_embeddings",
        index_params={
            "metric_type": "COSINE",
            "index_type": "IVF_FLAT",
            "params": {"nlist": 1024},
        },
    )

# %%
img_paths=glob.glob("data/Cliparts/01_Kate Hadfield/**/*.png", recursive=True)
imgs=pd.DataFrame({'path':img_paths})
imgs
# Out:
#                                                    path
# 0       data/Cliparts/01_Kate Hadfield/logo-cropped.png
# 1     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 2     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 3     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 4     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# ...                                                 ...
# 8212  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8213  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8214  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8215  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8216  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
#
# [8217 rows x 1 columns]

# %%
imgs['text']=imgs['path'].apply(lambda p:" ".join(rg.split(r'[\\|/_\\.-]', p)).strip())
imgs['img_embeddings']=[[]]*imgs.shape[0]
imgs['txt_embeddings']=[[]]*imgs.shape[0]
imgs
# Out:
#                                                    path  \
# 0       data/Cliparts/01_Kate Hadfield/logo-cropped.png
# 1     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 2     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 3     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 4     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# ...                                                 ...
# 8212  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8213  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8214  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8215  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8216  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
#
#                                                    text img_embeddings  \
# 0       data Cliparts 01 Kate Hadfield logo cropped png             []
# 1     data Cliparts 01 Kate Hadfield EggHunting khad...             []
# 2     data Cliparts 01 Kate Hadfield EggHunting khad...             []
# 3     data Cliparts 01 Kate Hadfield EggHunting khad...             []
# 4     data Cliparts 01 Kate Hadfield EggHunting khad...             []
# ...                                                 ...            ...
# 8212  data Cliparts 01 Kate Hadfield DoctorsAndNurse...             []
# 8213  data Cliparts 01 Kate Hadfield DoctorsAndNurse...             []
# 8214  data Cliparts 01 Kate Hadfield DoctorsAndNurse...             []
# 8215  data Cliparts 01 Kate Hadfield DoctorsAndNurse...             []
# 8216  data Cliparts 01 Kate Hadfield DoctorsAndNurse...             []
#
#      txt_embeddings
# 0                []
# 1                []
# 2                []
# 3                []
# 4                []
# ...             ...
# 8212             []
# 8213             []
# 8214             []
# 8215             []
# 8216             []
#
# [8217 rows x 4 columns]

# %%
imgs=imgs[imgs['path'].apply(lambda p:'stamp' not in p.lower())]
imgs
# Out:
#                                                    path  \
# 0       data/Cliparts/01_Kate Hadfield/logo-cropped.png
# 1     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 2     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 3     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 4     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# ...                                                 ...
# 8212  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8213  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8214  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8215  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 8216  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
#
#                                                    text  \
# 0       data Cliparts 01 Kate Hadfield logo cropped png
# 1     data Cliparts 01 Kate Hadfield EggHunting khad...
# 2     data Cliparts 01 Kate Hadfield EggHunting khad...
# 3     data Cliparts 01 Kate Hadfield EggHunting khad...
# 4     data Cliparts 01 Kate Hadfield EggHunting khad...
# ...                                                 ...
# 8212  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 8213  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 8214  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 8215  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 8216  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
#
#                                          img_embeddings  \
# 0     [-0.1224354059, 0.3337236047, -0.4869712591, 0...
# 1     [0.061049770600000004, -0.1090632156, -0.38299...
# 2     [-0.0441452377, 0.0552457534, -0.2363186777, 0...
# 3     [0.3908630013, 0.1392904371, 0.0251698196, 0.2...
# 4     [0.1650562286, -0.14565433560000002, 0.0494911...
# ...                                                 ...
# 8212  [0.1290355921, -0.1939580441, -0.395267278, 0....
# 8213  [0.1826949716, 0.22084504370000002, -0.2322636...
# 8214  [0.1671190262, 0.2088604718, -0.2348356694, 0....
# 8215  [0.1290355921, -0.1939580441, -0.395267278, 0....
# 8216  [0.1774400026, -0.1663113236, -0.2564328611, 0...
#
#                                          txt_embeddings
# 0     [0.11748978500000001, -0.033165860900000003, 0...
# 1     [-0.1486460865, -0.0283475928, 0.0670743361, -...
# 2     [-0.1432264298, -0.0117266253, 0.0473660268, -...
# 3     [-0.1174651235, 0.0058466634, 0.0603898764, -0...
# 4     [-0.1221045926, 0.0345767699, 0.0234132409, -0...
# ...                                                 ...
# 8212  [0.1815917343, 0.0183345601, 0.0043674563, -0....
# 8213  [0.13958533110000002, 0.0363522507, 0.03278619...
# 8214  [0.1449439079, 0.0388322063, 0.0345865823, -0....
# 8215  [0.1923192739, 0.0340455398, 0.0081001017, -0....
# 8216  [0.1962016672, 0.011078345600000001, -0.001184...
#
# [3423 rows x 4 columns]

# %%
n_batch = 256
g = imgs.index % n_batch
for idx,chunk in tqdm(imgs.groupby(g), 'encoding imgs'):    
    img_dat=[openImg(img) for img in chunk['path']]
    img_dict={i:d for i,d in enumerate(img_dat) if d is not None}
    # img_dat=torch.Tensor(img_dat).to(device)
    encodings=img_model.encode(list(img_dict.values()))
    results=[encodings[list(img_dict.keys()).index(i),...] if i in img_dict.keys() else np.zeros(encodings.shape[-1]) for i in range(len(img_dat))]
    result_series=pd.Series(results)
    result_series.index=chunk.index
    imgs.loc[chunk.index,'img_embeddings']=result_series
# Out:
# encoding imgs:   0%|          | 0/256 [00:00<?, ?it/s]
# /var/folders/w0/5b7f2srd2sb_56zjv17vqnym0000gn/T/ipykernel_68657/2808395122.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imgs.loc[chunk.index,'img_embeddings']=result_series
# cannot identify image file 'data/Cliparts/01_Kate Hadfield/WeekendAtHome/khadfield_WeekendAtHome_birdhouse.png'
# cannot identify image file 'data/Cliparts/01_Kate Hadfield/AVeryGermanChristmas/khadfield_AVeryGermanChristmas_adventcalendar2.png'
# cannot identify image file 'data/Cliparts/01_Kate Hadfield/MyKindaPet2/khadfield_MyKindaPet2_spider.png'
# cannot identify image file 'data/Cliparts/01_Kate Hadfield/FruitStand/khadfield_FruitStand_lemonslice2.png'
# cannot identify image file 'data/Cliparts/01_Kate Hadfield/SolarSystem/khadfield_SolarSystem_moon3.png'

# %%
for idx,chunk in tqdm(imgs.groupby(g), 'encoding texts'):
    img_texts=list(chunk['text'])
    encodings=text_model.encode(img_texts)
    results=[encodings[i,...] for i in range(len(img_texts))]
    result_series=pd.Series(results)
    result_series.index=chunk.index
    imgs.loc[chunk.index,'txt_embeddings']=result_series
# Out:
# encoding texts:   0%|          | 0/256 [00:00<?, ?it/s]
# /var/folders/w0/5b7f2srd2sb_56zjv17vqnym0000gn/T/ipykernel_68657/736080008.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imgs.loc[chunk.index,'txt_embeddings']=result_series

# %%
imgs.to_json('data/img_embedded_model_visual.json',orient='records')

# %%
imgs=pd.read_json('data/img_embedded_model_visual.json',orient='records')
imgs
# Out:
#                                                    path  \
# 0       data/Cliparts/01_Kate Hadfield/logo-cropped.png
# 1     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 2     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 3     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# 4     data/Cliparts/01_Kate Hadfield/EggHunting/khad...
# ...                                                 ...
# 3418  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 3419  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 3420  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 3421  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
# 3422  data/Cliparts/01_Kate Hadfield/DoctorsAndNurse...
#
#                                                    text  \
# 0       data Cliparts 01 Kate Hadfield logo cropped png
# 1     data Cliparts 01 Kate Hadfield EggHunting khad...
# 2     data Cliparts 01 Kate Hadfield EggHunting khad...
# 3     data Cliparts 01 Kate Hadfield EggHunting khad...
# 4     data Cliparts 01 Kate Hadfield EggHunting khad...
# ...                                                 ...
# 3418  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 3419  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 3420  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 3421  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
# 3422  data Cliparts 01 Kate Hadfield DoctorsAndNurse...
#
#                                          img_embeddings  \
# 0     [-0.1224354059, 0.3337236047, -0.4869712591, 0...
# 1     [0.061049770600000004, -0.1090632156, -0.38299...
# 2     [-0.0441452377, 0.0552457534, -0.2363186777, 0...
# 3     [0.3908630013, 0.1392904371, 0.0251698196, 0.2...
# 4     [0.1650562286, -0.14565433560000002, 0.0494911...
# ...                                                 ...
# 3418  [0.1290355176, -0.1939579695, -0.3952674568, 0...
# 3419  [0.1826951355, 0.2208450288, -0.23226381840000...
# 3420  [0.1671190709, 0.2088604271, -0.2348358035, 0....
# 3421  [0.1290355176, -0.1939579695, -0.3952674568, 0...
# 3422  [0.1774401069, -0.1663113087, -0.2564327717, 0...
#
#                                          txt_embeddings
# 0     [0.1174896359, -0.0331657864, 0.10817032310000...
# 1     [-0.14864604180000002, -0.0283475779, 0.067074...
# 2     [-0.1432264447, -0.0117265927, 0.0473659486, -...
# 3     [-0.1174652576, 0.0058467556000000006, 0.06038...
# 4     [-0.1221045852, 0.034576833200000004, 0.023413...
# ...                                                 ...
# 3418  [0.1815917343, 0.0183345601, 0.0043674563, -0....
# 3419  [0.13958533110000002, 0.0363522507, 0.03278619...
# 3420  [0.1449439079, 0.0388320014, 0.0345865935, -0....
# 3421  [0.1923192739, 0.0340455398, 0.0081001017, -0....
# 3422  [0.1962016672, 0.011078345600000001, -0.001184...
#
# [3423 rows x 4 columns]

# %%
def insert_into_db():
    global cliparts
    global cliparts_txt
    
    for i, rec in tqdm(imgs.iterrows(), total=imgs.shape[0]):
        d=rec.to_dict()
        if d['img_embeddings'] is None:
            print(d['path'], 'skipped!')
            continue
        cliparts.insert(d)
        cliparts_txt.insert(d)

    cliparts.load()
    cliparts_txt.load()

# %%
drop_collections()
setup_collections()
create_indices()
insert_into_db()
# Out:
#   0%|          | 0/3423 [00:00<?, ?it/s]
